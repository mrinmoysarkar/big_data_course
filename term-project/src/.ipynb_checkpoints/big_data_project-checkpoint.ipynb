# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import seaborn as sns
sns.set_style('white')
from sklearn.model_selection import train_test_split
from skimage.transform import resize

from keras.preprocessing.image import load_img
# from keras import Model
# from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# from keras.models import load_model
# from keras.optimizers import Adam
# from keras.utils.vis_utils import plot_model
# from keras.preprocessing.image import ImageDataGenerator
# from keras.layers import Input, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate, Dropout

from tqdm import tqdm_notebook

import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
img_size_ori = 101
img_size_target = 128

def upsample(img):
    if img_size_ori == img_size_target:
        return img
#     return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True)
    delta = img_size_target-img_size_ori
    d1 = delta//2
    d2 = delta-d1
    y = np.lib.pad(img, ((d1, d2), (d1, d2)), 'constant', constant_values=0)
    return y.ravel()

def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)

class batch_generator():
    def __init__(self,data):
        self.index = 0
        data['images'] = data['images'].apply(upsample)
        data['masks'] = data['masks'].apply(upsample)
        self.images = data['images'].values
        self.masks = data['masks'].values
        
    def get_xy_batch(self,batch_size):
        x = self.images[self.index:self.index+batch_size]
        y = self.masks[self.index:self.index+batch_size]
        self.index += batch_size
        return np.array(x.tolist()),np.array(y.tolist())
    def reset_index(self):
        self.index = 0

# %%
train_df = pd.read_csv("../data/train.csv", index_col="id", usecols=[0])
depths_df = pd.read_csv("../data/depths.csv", index_col="id")
train_df = train_df.join(depths_df)
test_df = depths_df[~depths_df.index.isin(train_df.index)]
total_no_of_train_samples = train_df.shape[0]

# %%
train_df["images"] = [np.array(load_img("../data/train/images/{}.png".format(idx), color_mode="grayscale")) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
train_df["masks"] = [np.array(load_img("../data/train/masks/{}.png".format(idx), color_mode="grayscale")) / 255 for idx in tqdm_notebook(train_df.index)]
# Out:
# HBox(children=(IntProgress(value=0, max=4000), HTML(value='')))

# %%
# print(train_df.head())
# train_df_temp = train_df
# train_df_temp['images'] = train_df_temp['images'].apply(upsample)
# train_df_temp['masks'] = train_df_temp['masks'].apply(upsample)

# %%
bg = batch_generator(train_df)
# x_train,y_train = bg.get_xy_batch(batch_size=20)

# %%
# print(list(y_train))
# print(np.array(x_train))
# print(type(x_train))
# x_train.shape

# %%
learning_rate = 0.001

x = tf.placeholder(tf.float32,shape=[None,16384])
y_true = tf.placeholder(tf.float32,shape=[None,16384])

inputs = tf.reshape(x,[-1,128,128,1])#tf.placeholder(tf.float32,shape=(None,128,128,1),name='inputs')
targets = tf.reshape(y_true,[-1,128,128,1])#tf.placeholder(tf.float32,shape=(None,128,128,1),name='targets')

# %%
conv1 = tf.layers.conv2d(inputs=inputs,filters=32,kernel_size=(3,3),padding='same',activation=tf.nn.relu)
maxpool1 = tf.layers.max_pooling2d(inputs=conv1,pool_size=(2,2),strides=(2,2),padding='same')

conv2 = tf.layers.conv2d(inputs=maxpool1,filters=32,kernel_size=(3,3),padding='same',activation=tf.nn.relu)
maxpool2 = tf.layers.max_pooling2d(inputs=conv2,pool_size=(2,2),strides=(2,2),padding='same')

conv3 = tf.layers.conv2d(inputs=maxpool2,filters=16,kernel_size=(3,3),padding='same',activation=tf.nn.relu)
maxpool3 = tf.layers.max_pooling2d(inputs=conv3,pool_size=(2,2),strides=(2,2),padding='same')

conv4 = tf.layers.conv2d(inputs=maxpool3,filters=16,kernel_size=(3,3),padding='same',activation=tf.nn.relu)
maxpool4 = tf.layers.max_pooling2d(inputs=conv4,pool_size=(2,2),strides=(2,2),padding='same')

conv5 = tf.layers.conv2d(inputs=maxpool4,filters=16,kernel_size=(3,3),padding='same',activation=tf.nn.relu)
encoded = tf.layers.max_pooling2d(inputs=conv5,pool_size=(2,2),strides=(2,2),padding='same')

# %%
upsampler1 = tf.image.resize_images(encoded,size=(8,8),method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
conv6 = tf.layers.conv2d(inputs=upsampler1,filters=16,kernel_size=(3,3),padding='same',activation=tf.nn.relu)

upsampler2 = tf.image.resize_images(conv6,size=(16,16),method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
conv7 = tf.layers.conv2d(inputs=upsampler2,filters=16,kernel_size=(3,3),padding='same',activation=tf.nn.relu)

upsampler3 = tf.image.resize_images(conv7,size=(32,32),method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
conv8 = tf.layers.conv2d(inputs=upsampler3,filters=16,kernel_size=(3,3),padding='same',activation=tf.nn.relu)

upsampler4 = tf.image.resize_images(conv8,size=(64,64),method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
conv9 = tf.layers.conv2d(inputs=upsampler4,filters=32,kernel_size=(3,3),padding='same',activation=tf.nn.relu)

upsampler5 = tf.image.resize_images(conv9,size=(128,128),method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
conv10 = tf.layers.conv2d(inputs=upsampler5,filters=32,kernel_size=(3,3),padding='same',activation=tf.nn.relu)

# %%
logits = tf.layers.conv2d(inputs=conv10,filters=1,kernel_size=(3,3),padding='same',activation=None)
decoded = tf.nn.sigmoid(logits)
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets,logits=logits)
cost = tf.reduce_mean(loss)
optimizer = tf.train.AdadeltaOptimizer(learning_rate=learning_rate).minimize(cost)

# %%
# with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))
if True:
    options = tf.RunOptions(output_partition_graphs=True)
    metadata = tf.RunMetadata()
    print(sess.run(tf.global_variables_initializer(),options=options, run_metadata=metadata))
    print(metadata.partition_graphs)
    epochs = 1
    batch_size = 10
    for e in range(epochs):
        bg.reset_index()
        for ii in range(3):#total_no_of_train_samples//batch_size):
            x_train,y_train = bg.get_xy_batch(batch_size=batch_size)
#             batch_cost, _ = sess.run([cost,optimizer],feed_dict={x:x_train,y_true:y_train})
#             print("Trainning loss: {:.4f}".format(batch_cost))
            print(sess.run([cost,optimizer],feed_dict={x:x_train,y_true:y_train},options=options, run_metadata=metadata))
            print(metadata.partition_graphs)
# Out:
# None
# [node {
#   name: "conv2d/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 32
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 1
#         }
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 1
#         }
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d/kernel/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#           dim {
#             size: 3
#           }
#           dim {
#             size: 1
#           }
#           dim {
#             size: 32
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 1
#         }
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\001\000\000\000 \000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.14213381707668304
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_1/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_1/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_1/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_1/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 32
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_1/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_1/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_1/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 32
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_1/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000 \000\000\000 \000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_1/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_1/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.10206207633018494
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_10/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_10/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_10/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_10/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_10/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_10/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_10/kernel/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#           dim {
#             size: 3
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 1
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_10/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 1
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_10/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000 \000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d/kernel/Initializer/random_uniform/sub"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         tensor_content: "\207\213\221>"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_10/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_10/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.14213381707668304
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_2/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_2/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_2/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_2/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_2/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_2/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_2/kernel/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#           dim {
#             size: 3
#           }
#           dim {
#             size: 32
#           }
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_2/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 32
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_2/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000 \000\000\000\020\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_2/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_2/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.1178511306643486
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_3/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_3/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_3/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_3/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_3/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_3/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_3/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_3/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\020\000\000\000\020\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_3/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_3/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.14433756470680237
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_4/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_4/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_4/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_4/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_4/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_4/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_4/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_4/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\020\000\000\000\020\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_4/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_4/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.14433756470680237
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_5/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_5/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_5/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_5/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_5/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_5/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_5/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_5/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\020\000\000\000\020\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_5/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_5/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.14433756470680237
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_6/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_6/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_6/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_6/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_6/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_6/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_6/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_6/kernel/Initializer/random_uniform/shape"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\020\000\000\000\020\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_6/kernel/Initializer/random_uniform/min"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_6/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.14433756470680237
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_7/bias/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_7/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_7/bias/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_7/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_7/bias"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_7/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_7/bias/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_7/bias/Assign"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_7/kernel/Adadelta"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_7/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_7/kernel/Adadelta_1"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_7/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 16
#         }
#         dim {
#           size: 16
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2d_3/kernel/Adadelta/Initializer/zeros"
#   op: "Const"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 3
#           }
#           dim {
#             size: 3
#           }
#           dim {
#             size: 16
#           }
#           dim {
#             size: 16
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2d_7/kernel"
#   op: "VariableV2"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2d_7/kernel/Assign"
#       }
#     }
#   }
#   attr {
#     key: "container"
# ...
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d_3/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_3/Conv2D_grad/Conv2DBackpropFilter"
#   op: "Conv2DBackpropFilter"
#   input: "max_pooling2d_2/MaxPool"
#   input: "ConstantFolding/gradients/conv2d_3/Conv2D_grad/ShapeN-matshapes-1"
#   input: "gradients/conv2d_3/Relu_grad/ReluGrad"
#   input: "^gradients/conv2d_3/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "dilations"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "use_cudnn_on_gpu"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_3/Conv2D_grad/Conv2DBackpropInput"
#   op: "Conv2DBackpropInput"
#   input: "gradients/conv2d_3/Conv2D_grad/ShapeN"
#   input: "conv2d_3/kernel/read"
#   input: "gradients/conv2d_3/Relu_grad/ReluGrad"
#   input: "^gradients/conv2d_3/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "dilations"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "use_cudnn_on_gpu"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "gradients/max_pooling2d_2/MaxPool_grad/MaxPoolGrad"
#   op: "MaxPoolGrad"
#   input: "conv2d_2/Relu"
#   input: "max_pooling2d_2/MaxPool"
#   input: "gradients/conv2d_3/Conv2D_grad/Conv2DBackpropInput"
#   input: "^gradients/conv2d_3/Conv2D_grad/Conv2DBackpropFilter"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "ksize"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "Adadelta/update_conv2d_3/kernel/ApplyAdadelta"
#   op: "ApplyAdadelta"
#   input: "conv2d_3/kernel"
#   input: "conv2d_3/kernel/Adadelta"
#   input: "conv2d_3/kernel/Adadelta_1"
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d_3/Conv2D_grad/Conv2DBackpropFilter"
#   input: "^gradients/conv2d_3/Conv2D_grad/Conv2DBackpropInput"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_2/Relu_grad/ReluGrad"
#   op: "ReluGrad"
#   input: "gradients/max_pooling2d_2/MaxPool_grad/MaxPoolGrad"
#   input: "conv2d_2/Relu"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_2/BiasAdd_grad/BiasAddGrad"
#   op: "BiasAddGrad"
#   input: "gradients/conv2d_2/Relu_grad/ReluGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
# }
# node {
#   name: "Adadelta/update_conv2d_2/bias/ApplyAdadelta"
#   op: "ApplyAdadelta"
#   input: "conv2d_2/bias"
#   input: "conv2d_2/bias/Adadelta"
#   input: "conv2d_2/bias/Adadelta_1"
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d_2/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_2/Conv2D_grad/Conv2DBackpropFilter"
#   op: "Conv2DBackpropFilter"
#   input: "max_pooling2d_1/MaxPool"
#   input: "ConstantFolding/gradients/conv2d_2/Conv2D_grad/ShapeN-matshapes-1"
#   input: "gradients/conv2d_2/Relu_grad/ReluGrad"
#   input: "^gradients/conv2d_2/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "dilations"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "use_cudnn_on_gpu"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_2/Conv2D_grad/Conv2DBackpropInput"
#   op: "Conv2DBackpropInput"
#   input: "gradients/conv2d_2/Conv2D_grad/ShapeN"
#   input: "conv2d_2/kernel/read"
#   input: "gradients/conv2d_2/Relu_grad/ReluGrad"
#   input: "^gradients/conv2d_2/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "dilations"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "use_cudnn_on_gpu"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "gradients/max_pooling2d_1/MaxPool_grad/MaxPoolGrad"
#   op: "MaxPoolGrad"
#   input: "conv2d_1/Relu"
#   input: "max_pooling2d_1/MaxPool"
#   input: "gradients/conv2d_2/Conv2D_grad/Conv2DBackpropInput"
#   input: "^gradients/conv2d_2/Conv2D_grad/Conv2DBackpropFilter"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "ksize"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "Adadelta/update_conv2d_2/kernel/ApplyAdadelta"
#   op: "ApplyAdadelta"
#   input: "conv2d_2/kernel"
#   input: "conv2d_2/kernel/Adadelta"
#   input: "conv2d_2/kernel/Adadelta_1"
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d_2/Conv2D_grad/Conv2DBackpropFilter"
#   input: "^gradients/conv2d_2/Conv2D_grad/Conv2DBackpropInput"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_1/Relu_grad/ReluGrad"
#   op: "ReluGrad"
#   input: "gradients/max_pooling2d_1/MaxPool_grad/MaxPoolGrad"
#   input: "conv2d_1/Relu"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_1/BiasAdd_grad/BiasAddGrad"
#   op: "BiasAddGrad"
#   input: "gradients/conv2d_1/Relu_grad/ReluGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
# }
# node {
#   name: "Adadelta/update_conv2d_1/bias/ApplyAdadelta"
#   op: "ApplyAdadelta"
#   input: "conv2d_1/bias"
#   input: "conv2d_1/bias/Adadelta"
#   input: "conv2d_1/bias/Adadelta_1"
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d_1/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_1/Conv2D_grad/Conv2DBackpropFilter"
#   op: "Conv2DBackpropFilter"
#   input: "max_pooling2d/MaxPool"
#   input: "ConstantFolding/gradients/conv2d_1/Conv2D_grad/ShapeN-matshapes-1"
#   input: "gradients/conv2d_1/Relu_grad/ReluGrad"
#   input: "^gradients/conv2d_1/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "dilations"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "use_cudnn_on_gpu"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "gradients/conv2d_1/Conv2D_grad/Conv2DBackpropInput"
#   op: "Conv2DBackpropInput"
#   input: "gradients/conv2d_1/Conv2D_grad/ShapeN"
#   input: "conv2d_1/kernel/read"
#   input: "gradients/conv2d_1/Relu_grad/ReluGrad"
#   input: "^gradients/conv2d_1/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "dilations"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "use_cudnn_on_gpu"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "gradients/max_pooling2d/MaxPool_grad/MaxPoolGrad"
#   op: "MaxPoolGrad"
#   input: "conv2d/Relu"
#   input: "max_pooling2d/MaxPool"
#   input: "gradients/conv2d_1/Conv2D_grad/Conv2DBackpropInput"
#   input: "^gradients/conv2d_1/Conv2D_grad/Conv2DBackpropFilter"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "ksize"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "Adadelta/update_conv2d_1/kernel/ApplyAdadelta"
#   op: "ApplyAdadelta"
#   input: "conv2d_1/kernel"
#   input: "conv2d_1/kernel/Adadelta"
#   input: "conv2d_1/kernel/Adadelta_1"
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d_1/Conv2D_grad/Conv2DBackpropFilter"
#   input: "^gradients/conv2d_1/Conv2D_grad/Conv2DBackpropInput"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/conv2d/Relu_grad/ReluGrad"
#   op: "ReluGrad"
#   input: "gradients/max_pooling2d/MaxPool_grad/MaxPoolGrad"
#   input: "conv2d/Relu"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "gradients/conv2d/BiasAdd_grad/BiasAddGrad"
#   op: "BiasAddGrad"
#   input: "gradients/conv2d/Relu_grad/ReluGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
# }
# node {
#   name: "Adadelta/update_conv2d/bias/ApplyAdadelta"
#   op: "ApplyAdadelta"
#   input: "conv2d/bias"
#   input: "conv2d/bias/Adadelta"
#   input: "conv2d/bias/Adadelta_1"
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "gradients/conv2d/Conv2D_grad/Conv2DBackpropFilter"
#   op: "Conv2DBackpropFilter"
#   input: "Reshape"
#   input: "ConstantFolding/gradients/conv2d/Conv2D_grad/ShapeN-matshapes-1"
#   input: "gradients/conv2d/Relu_grad/ReluGrad"
#   input: "^gradients/conv2d/BiasAdd_grad/BiasAddGrad"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "dilations"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "use_cudnn_on_gpu"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Adadelta/update_conv2d/kernel/ApplyAdadelta"
#   op: "ApplyAdadelta"
#   input: "conv2d/kernel"
#   input: "conv2d/kernel/Adadelta"
#   input: "conv2d/kernel/Adadelta_1"
#   input: "Adadelta/lr"
#   input: "Adadelta/rho"
#   input: "Adadelta/epsilon"
#   input: "gradients/conv2d/Conv2D_grad/Conv2DBackpropFilter"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: false
#     }
#   }
# }
# node {
#   name: "Adadelta"
#   op: "NoOp"
#   input: "^Adadelta/update_conv2d/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_1/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_1/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_10/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_10/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_2/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_2/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_3/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_3/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_4/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_4/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_5/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_5/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_6/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_6/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_7/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_7/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_8/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_8/kernel/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_9/bias/ApplyAdadelta"
#   input: "^Adadelta/update_conv2d_9/kernel/ApplyAdadelta"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
# }
# node {
#   name: "_retval_Mean_0_0"
#   op: "_Retval"
#   input: "Mean"
#   device: "/job:localhost/replica:0/task:0/device:CPU:0"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "index"
#     value {
#       i: 0
#     }
#   }
# }
# library {
# }
# versions {
#   producer: 26
# }
# ]
